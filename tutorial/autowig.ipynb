# %% [markdown]
# # `AutoWIG`: a Python package for the automatic generation of Python bindings for C++ libraries

# %% [markdown]
# ## Introduction
#
# Python is one of the most popular programming language in scientific computing.
# However, most scientifc Python libraries relies on some C and C++ libraries.
# While several semi-automatic solution and tools exist to wrap large C++ libraries (Cython, Boost.Python and SWIG), the process of wrapping a large C++ library is cumbersome and time consumming.
# Some solutions have been developped in the past (e.g. Py++) but require to write complex code to automate the process, and rely on technologies that are not maintained.
# AutoWIG relies on the LLVM/Clang technology for parsing C/C++ code and the Mako templating engine for generating Boost.Python wrappers.
# Rather than having to write parsers in Python like in Py++, the approach is similar to XDress, but for Boost.Python wrappers instead of Cython wrappers.
# We will demonstrate the use of AutoWIG on a complex collection of C++ libraries for statistical analysis.
#
# [AutoWIG (Automatic Wrapper and Interface Generator)](https://github.com/VirtualPlants/autowig) is an automatic wrapper generator for C/C++ libraries written in Python and based on [LLVM/Clang](http://clang.llvm.org/).
# It generates Boost.Python code for C/C++ enumerations, variables, functions, C structures and C++ classes in order to provide Python bindings for C/C++ libraries.
#
# The main features of AutoWIG are:
#
# *   The automatic construction of Abstract Semantic Graphs (ASGs) in Python from Abstract Syntax Trees (ASTs) given by LLVM/Clang.
# *   The versatile generation of Python bindings using the Python [Mako](http://www.makotemplates.org) templating engine.
#
# ASTs produced by LLVM/Clang are not capable of representing shared subexpressions due to their simplistic structure, this simplicity comes at a cost of efficiency due to redundant duplicate computations of identical terms.
# AutoWIG therefore constructs an ASG from a LLVM/Clang AST by a process of enrichment and abstraction.
# This enrichment can for example be the addition of nodes (types) and edges to represent variables or parameters types.
# The abstraction entail the removal of details which are relevant only in parsing, such as forward declarations.
# In particular this ASG representation enables code introspection via graph traversals such as the inquiry of number of classes, list of class methods, list of all types of inputs and outputs considered in class methods...
# This provides an efficient and simple way to produces minimal induced subgraphs of C/C++ library ASGs where minimal stands for the addition of a minimal number of vertices to a given subset of vertices in order to obtain an induced subgraph of the ASG.
#
# The use of a templating engine for the wrapper generation consists in the use of a default template that can be applied to any node (or set of nodes) of an ASG in order to produce the corresponding Boost.Python wrapper.
# This template concentrate the Boost.Python knowledge required to produce reflexive wrappers.
# Since for some C++ libraries this behaviour is not wanted or would need slight modifications, this template is encapsulated into a class that can be derived in order to adapt the wanted bindings.
# The wrapper generation step of AutoWIG is therefore considered as a collection of Python scripts specifying the template to consider and nodes targeted.
#
# Currently the AutoWIG package is integrated into [SCons](http://www.scons.org/) via the definition of builders for [OpenAlea](http://openalea.gforge.inria.fr/dokuwiki/doku.php) packages.
# Future work considered is the implementation of magic cells for [IPython Notebooks](http://ipython.org/notebook.html) and [OpenAleaLab](https://github.com/openalea/openalea/wiki/Roadmap:-OpenAleaLab) in order to provide a simple way to integrate C/C++ code into Python notebooks and workflows.
# Note that the comparison with state of the art wrapper generators (such as [XDress](http://xdress.org/latest/index.html)) is also envisaged.
# In particular, such a comparison could lead to a deeper investigation of the respective advantages and inconvenients of Boost.Python and Cython wrappers.
#
# This talk will focus on the generation of Python bindings for C++ libraries.
# This will be illustrated by the bootstrapping of LLVM/Clang Python bindings in order to enable the generation of wrappers for template class instantiated.
# The case of Python bindings generation for multiple C++ libraries (for statistical analysis) with dependencies will also be discussed (in particular with C++ standard library containers).

# %% [markdown]
# ## Project vision

# %% [markdown]
# ### Activies

# %% [markdown]
# ![Vision](autowig/vision.png)

# %% [markdown]
# ### Structure of a compiler
# Compilers bridge source programs in high-level languages with the underlying hardware. A compiler verifies code syntax, generates efficient object code, performs run-time organization, and formats the output according to assembler and linker conventions. A compiler consists of:
#
# * The front end: Verifies syntax and semantics, and generates an intermediate representation or IR of the source code for processing by the middle-end. Performs type checking by collecting type information. Generates errors and warning, if any, in a useful way. Aspects of the front end include lexical analysis, syntax analysis, and semantic analysis.
# * The middle end: Performs optimizations, including removal of useless or unreachable code, discovery and propagation of constant values, relocation of computation to a less frequently executed place (e.g., out of a loop), or specialization of computation based on the context. Generates another IR for the backend.
# * The back end: Generates the assembly code, performing register allocation in process. (Assigns processor registers for the program variables where possible.) Optimizes target code utilization of the hardware by figuring out how to keep parallel execution units busy, filling delay slots. Although most algorithms for optimization are in NP, heuristic techniques are well-developed.

# %% [markdown]
# ## Underlying technologies

# %% [markdown]
# ## Examples

# %%
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = 14, 5
mpl.rcParams['savefig.dpi'] = 80
mpl.rcParams['savefig.bbox'] = 'tight'
# %load_ext vplants.autowig.ipython

# %% [markdown]
# ### PyClangLite
#
# #### Front end

# %%
# %reset -f

includedir = "/usr/local/include"

headers = ["clang/AST/ExternalASTSource.h", "clang/AST/DependentDiagnostic.h", "clang/AST/ParentMap.h",
           "clang/AST/DeclGroup.h", "clang/AST/DeclAccessPair.h", "clang/AST/UnresolvedSet.h",
           "clang/AST/DeclarationName.h", "clang/AST/Stmt.h", "clang/AST/Redeclarable.h", "clang/AST/Type.h",
           "clang/AST/SelectorLocationsKind.h", "clang/AST/ExprObjC.h", "clang/AST/OperationKinds.h",
           "clang/AST/DeclObjC.h", "clang/AST/CXXInheritance.h", "clang/AST/CommentLexer.h",
           "clang/AST/ASTTypeTraits.h", "clang/AST/TemplateBase.h", "clang/AST/DeclFriend.h", 
           "clang/AST/OpenMPClause.h", "clang/AST/DeclLookups.h", "clang/AST/StmtVisitor.h",
           "clang/AST/VTableBuilder.h", "clang/AST/ASTUnresolvedSet.h", "clang/AST/GlobalDecl.h",
           "clang/AST/DeclBase.h", "clang/AST/ASTContext.h", "clang/AST/CharUnits.h", "clang/AST/StmtOpenMP.h",
           "clang/AST/TypeLocVisitor.h", "clang/AST/LambdaCapture.h", "clang/AST/CanonicalType.h",
           "clang/AST/PrettyPrinter.h", "clang/AST/CommentCommandTraits.h", "clang/AST/NestedNameSpecifier.h",
           "clang/AST/DeclTemplate.h", "clang/AST/Mangle.h", "clang/AST/StmtIterator.h", "clang/AST/Attr.h",
           "clang/AST/StmtGraphTraits.h", "clang/AST/MangleNumberingContext.h", "clang/AST/StmtCXX.h",
           "clang/AST/CommentSema.h", "clang/AST/RecursiveASTVisitor.h", "clang/AST/ASTConsumer.h",
           "clang/AST/ASTFwd.h", "clang/AST/TypeLoc.h", "clang/AST/CommentDiagnostic.h",
           "clang/AST/VTTBuilder.h", "clang/AST/EvaluatedExprVisitor.h", "clang/AST/CommentParser.h",
           "clang/AST/AttrIterator.h", "clang/AST/DataRecursiveASTVisitor.h", "clang/AST/NSAPI.h",
           "clang/AST/TypeOrdering.h", "clang/AST/TypeVisitor.h", "clang/AST/Decl.h", "clang/AST/ExprCXX.h",
           "clang/AST/CommentVisitor.h", "clang/AST/ASTDiagnostic.h", "clang/AST/AST.h", "clang/AST/ASTLambda.h",
           "clang/AST/StmtObjC.h", "clang/AST/RecordLayout.h", "clang/AST/APValue.h",
           "clang/AST/DeclContextInternals.h", "clang/AST/TemplateName.h", "clang/AST/ASTImporter.h",
           "clang/AST/DeclOpenMP.h", "clang/AST/ASTMutationListener.h", "clang/AST/RawCommentList.h",
           "clang/AST/ASTVector.h", "clang/AST/Comment.h", "clang/AST/DeclCXX.h", "clang/AST/CommentBriefParser.h",
           "clang/AST/Expr.h", "clang/AST/BaseSubobject.h", "clang/AST/DeclVisitor.h", "clang/Frontend/ASTUnit.h",
           "clang/Basic/Specifiers.h"]

headers = [includedir + '/' + header for header in headers]

flags = ['-x', 'c++', '-g', '-std=c++11', '-I'+includedir]

# %% [raw]
# from vplants.autowig.front_end import *
# ast = AbstractSyntaxTree()
# ast.front_end('libclang', *headers, flags=flags, libpath='/usr/local/lib/libclang.so')
# print ast

# %%
from vplants.autowig.front_end import *
asg = AbstractSemanticGraph()
asg.front_end('libclang', *headers, flags=flags, libpath='/usr/local/lib/libclang.so', silent=True)
# Out:
# done!
# 0 done!

# %%
asg

# %% [markdown]
# #### Middle end

# %%
from vplants.autowig.middle_end import *
asg.middle_end('bootstrap')

# %%
asg

# %% [markdown]
# #### Back end

# %%
from vplants.autowig.back_end import *
asg.back_end('bootstrap', '../../pyclanglite/src/wrapper/pyclanglite.cpp', on_disk=True)
# Out:
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/boost_python_back_end.py:565: BackEndWarning: ::llvm::FoldingSetNode
#   warnings.warn(bse.node, BackEndWarning)
# <table>
# 	<tr>
# 		<th>Total files generated</th>
# 		<td>146 <i>(f)</i></td>
# 	</tr>
# 	<tr>
# 		<th>Total physical source lines of code</th>
# 		<td>2393 <i>(l)</i></td>
# 	</tr>
# 	<tr>
# 		<th>Elapsed time</th>
# 		<td>0.73 <i>(s)</i></td>
# 	</tr>
# 	<tr>
# 		<th> Basic COCOMO model software project</th>
# 		<td>semi-detached</td>
# 	</tr>
# 	<tr>
# 		<th>Development effort estimate</th>
# 		<td>7.97 <i>(p/m)</i></td>
# 	</tr>
# 	<tr>
# 		<th>Schedule estimate</th>
# 		<td>5.17 <i>(m)</i></td>
# 	</tr>
# 	<tr>
# 		<th>Estimated average number of developers</th>
# 		<td>1.54 <i>(p)</i></td>
# 	</tr>
# </table>

# %%
asg

# %% [markdown]
# #### SCons

# %%
from vplants.autowig.scons import *
asg.add_sconstruct('../../pyclanglite')
asg.scons('-j', '3')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
#
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# td.linenos { background-color: #f0f0f0; padding-right: 10px; }
# span.lineno { background-color: #f0f0f0; padding: 0 5px 0 5px; }
# pre { line-height: 125%; }
# body .hll { background-color: #ffffcc }
# body  { background: #f8f8f8; }
# body .c { color: #408080; font-style: italic } /* Comment */
# body .err { border: 1px solid #FF0000 } /* Error */
# body .k { color: #008000; font-weight: bold } /* Keyword */
# body .o { color: #666666 } /* Operator */
# body .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# body .cp { color: #BC7A00 } /* Comment.Preproc */
# body .c1 { color: #408080; font-style: italic } /* Comment.Single */
# body .cs { color: #408080; font-style: italic } /* Comment.Special */
# body .gd { color: #A00000 } /* Generic.Deleted */
# body .ge { font-style: italic } /* Generic.Emph */
# body .gr { color: #FF0000 } /* Generic.Error */
# body .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# body .gi { color: #00A000 } /* Generic.Inserted */
# body .go { color: #888888 } /* Generic.Output */
# body .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# body .gs { font-weight: bold } /* Generic.Strong */
# body .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# body .gt { color: #0044DD } /* Generic.Traceback */
# body .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #008000 } /* Keyword.Pseudo */
# body .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #B00040 } /* Keyword.Type */
# body .m { color: #666666 } /* Literal.Number */
# body .s { color: #BA2121 } /* Literal.String */
# body .na { color: #7D9029 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# body .no { color: #880000 } /* Name.Constant */
# body .nd { color: #AA22FF } /* Name.Decorator */
# body .ni { color: #999999; font-weight: bold } /* Name.Entity */
# body .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# body .nf { color: #0000FF } /* Name.Function */
# body .nl { color: #A0A000 } /* Name.Label */
# body .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# body .nt { color: #008000; font-weight: bold } /* Name.Tag */
# body .nv { color: #19177C } /* Name.Variable */
# body .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# body .w { color: #bbbbbb } /* Text.Whitespace */
# body .mf { color: #666666 } /* Literal.Number.Float */
# body .mh { color: #666666 } /* Literal.Number.Hex */
# body .mi { color: #666666 } /* Literal.Number.Integer */
# body .mo { color: #666666 } /* Literal.Number.Oct */
# body .sb { color: #BA2121 } /* Literal.String.Backtick */
# body .sc { color: #BA2121 } /* Literal.String.Char */
# body .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# body .s2 { color: #BA2121 } /* Literal.String.Double */
# body .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# body .sh { color: #BA2121 } /* Literal.String.Heredoc */
# body .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# body .sx { color: #008000 } /* Literal.String.Other */
# body .sr { color: #BB6688 } /* Literal.String.Regex */
# body .s1 { color: #BA2121 } /* Literal.String.Single */
# body .ss { color: #19177C } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .vc { color: #19177C } /* Name.Variable.Class */
# body .vg { color: #19177C } /* Name.Variable.Global */
# body .vi { color: #19177C } /* Name.Variable.Instance */
# body .il { color: #666666 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span class="go">scons: Reading SConscript files ...</span>
# <span class="go">scons: done reading SConscript files.</span>
# <span class="go">scons: Building targets ...</span>
# <span class="go">g++ -o build-scons/src/wrapper/export_class_clang_decl.os -c -DNDEBUG -O2 -std=c++0x -DNDEBUG -O2 -fPIC -ftemplate-depth-100 -DBOOST_PYTHON_DYNAMIC_LIB -Ibuild-scons/include -I/usr/include -I/usr/include/python2.7 -I/usr/local/include build-scons/src/wrapper/export_class_clang_decl.cpp</span>
# <span class="go">g++ -o build-scons/src/wrapper/export_class_clang_decl_context.os -c -DNDEBUG -O2 -std=c++0x -DNDEBUG -O2 -fPIC -ftemplate-depth-100 -DBOOST_PYTHON_DYNAMIC_LIB -Ibuild-scons/include -I/usr/include -I/usr/include/python2.7 -I/usr/local/include build-scons/src/wrapper/export_class_clang_decl_context.cpp</span>
# <span class="go">g++ -o build-scons/src/wrapper/export_class_clang_function_decl.os -c -DNDEBUG -O2 -std=c++0x -DNDEBUG -O2 -fPIC -ftemplate-depth-100 -DBOOST_PYTHON_DYNAMIC_LIB -Ibuild-scons/include -I/usr/include -I/usr/include/python2.7 -I/usr/local/include build-scons/src/wrapper/export_class_clang_function_decl.cpp</span>
# <span class="go">g++ -o build-scons/src/wrapper/pyclanglite.os -c -DNDEBUG -O2 -std=c++0x -DNDEBUG -O2 -fPIC -ftemplate-depth-100 -DBOOST_PYTHON_DYNAMIC_LIB -Ibuild-scons/include -I/usr/include -I/usr/include/python2.7 -I/usr/local/include build-scons/src/wrapper/pyclanglite.cpp</span>
# <span class="go">g++ -o build-scons/src/wrapper/export_namespace_clang_cast.os -c -DNDEBUG -O2 -std=c++0x -DNDEBUG -O2 -fPIC -ftemplate-depth-100 -DBOOST_PYTHON_DYNAMIC_LIB -Ibuild-scons/include -I/usr/include -I/usr/include/python2.7 -I/usr/local/include build-scons/src/wrapper/export_namespace_clang_cast.cpp</span>
# <span class="go">g++ -o src/pyclanglite/_pyclanglite.so -shared build-scons/src/wrapper/export_class_clang_member_pointer_type.os build-scons/src/wrapper/export_class_clang_enum_type.os build-scons/src/wrapper/export_class_clang_var_decl.os build-scons/src/wrapper/export_class_clang_file_scope_asm_decl.os build-scons/src/wrapper/export_class_clang_split_qual_type.os build-scons/src/wrapper/export_class_clang_type_of_expr_type.os build-scons/src/wrapper/export_class_clang_obj_cat_defs_field_decl.os build-scons/src/wrapper/export_class_clang_class_template_decl.os build-scons/src/wrapper/export_class_clang_cxxmethod_decl.os build-scons/src/wrapper/export_class_clang_static_assert_decl.os build-scons/src/wrapper/export_class_clang_cxxdestructor_decl.os build-scons/src/wrapper/export_class_clang_extern_ccontext_decl.os build-scons/src/wrapper/export_class_clang_indirect_field_decl.os build-scons/src/wrapper/export_class_clang_decl.os build-scons/src/wrapper/export_enum_clang_linkage_spec_decl_language_ids.os build-scons/src/wrapper/export_class_clang_type_with_keyword.os build-scons/src/wrapper/export_class_clang_field_decl.os build-scons/src/wrapper/export_class_clang_enum_decl.os build-scons/src/wrapper/export_class_clang_incomplete_array_type.os build-scons/src/wrapper/export_class_llvm_folding_set_impl_node.os build-scons/src/wrapper/export_class_clang_implicit_param_decl.os build-scons/src/wrapper/export_class_clang_obj_ccompatible_alias_decl.os build-scons/src/wrapper/export_class_clang_function_type.os build-scons/src/wrapper/export_class_clang_friend_decl.os build-scons/src/wrapper/export_class_clang_linkage_spec_decl.os build-scons/src/wrapper/export_class_clang_decl_context.os build-scons/src/wrapper/export_class_clang_pretty_stack_trace_decl.os build-scons/src/wrapper/export_class_clang_var_template_decl.os build-scons/src/wrapper/export_class_clang_constant_array_type.os build-scons/src/wrapper/export_class_clang_tag_decl.os build-scons/src/wrapper/export_class_clang_complex_type.os build-scons/src/wrapper/export_class_clang_function_no_proto_type.os build-scons/src/wrapper/export_class_clang_global_decl.os build-scons/src/wrapper/export_class_clang_unresolved_using_value_decl.os build-scons/src/wrapper/export_class_clang_typede

# %% [markdown]
# #### Test

# %%
# %reset -f

includedir = "/usr/local/include"

headers = ["clang/AST/ExternalASTSource.h", "clang/AST/DependentDiagnostic.h", "clang/AST/ParentMap.h",
           "clang/AST/DeclGroup.h", "clang/AST/DeclAccessPair.h", "clang/AST/UnresolvedSet.h",
           "clang/AST/DeclarationName.h", "clang/AST/Stmt.h", "clang/AST/Redeclarable.h", "clang/AST/Type.h",
           "clang/AST/SelectorLocationsKind.h", "clang/AST/ExprObjC.h", "clang/AST/OperationKinds.h",
           "clang/AST/DeclObjC.h", "clang/AST/CXXInheritance.h", "clang/AST/CommentLexer.h",
           "clang/AST/ASTTypeTraits.h", "clang/AST/TemplateBase.h", "clang/AST/DeclFriend.h", 
           "clang/AST/OpenMPClause.h", "clang/AST/DeclLookups.h", "clang/AST/StmtVisitor.h",
           "clang/AST/VTableBuilder.h", "clang/AST/ASTUnresolvedSet.h", "clang/AST/GlobalDecl.h",
           "clang/AST/DeclBase.h", "clang/AST/ASTContext.h", "clang/AST/CharUnits.h", "clang/AST/StmtOpenMP.h",
           "clang/AST/TypeLocVisitor.h", "clang/AST/LambdaCapture.h", "clang/AST/CanonicalType.h",
           "clang/AST/PrettyPrinter.h", "clang/AST/CommentCommandTraits.h", "clang/AST/NestedNameSpecifier.h",
           "clang/AST/DeclTemplate.h", "clang/AST/Mangle.h", "clang/AST/StmtIterator.h", "clang/AST/Attr.h",
           "clang/AST/StmtGraphTraits.h", "clang/AST/MangleNumberingContext.h", "clang/AST/StmtCXX.h",
           "clang/AST/CommentSema.h", "clang/AST/RecursiveASTVisitor.h", "clang/AST/ASTConsumer.h",
           "clang/AST/ASTFwd.h", "clang/AST/TypeLoc.h", "clang/AST/CommentDiagnostic.h",
           "clang/AST/VTTBuilder.h", "clang/AST/EvaluatedExprVisitor.h", "clang/AST/CommentParser.h",
           "clang/AST/AttrIterator.h", "clang/AST/DataRecursiveASTVisitor.h", "clang/AST/NSAPI.h",
           "clang/AST/TypeOrdering.h", "clang/AST/TypeVisitor.h", "clang/AST/Decl.h", "clang/AST/ExprCXX.h",
           "clang/AST/CommentVisitor.h", "clang/AST/ASTDiagnostic.h", "clang/AST/AST.h", "clang/AST/ASTLambda.h",
           "clang/AST/StmtObjC.h", "clang/AST/RecordLayout.h", "clang/AST/APValue.h",
           "clang/AST/DeclContextInternals.h", "clang/AST/TemplateName.h", "clang/AST/ASTImporter.h",
           "clang/AST/DeclOpenMP.h", "clang/AST/ASTMutationListener.h", "clang/AST/RawCommentList.h",
           "clang/AST/ASTVector.h", "clang/AST/Comment.h", "clang/AST/DeclCXX.h", "clang/AST/CommentBriefParser.h",
           "clang/AST/Expr.h", "clang/AST/BaseSubobject.h", "clang/AST/DeclVisitor.h", "clang/Frontend/ASTUnit.h",
           "clang/Basic/Specifiers.h"]

headers = [includedir + '/' + header for header in headers]

flags = ['-x', 'c++', '-g', '-std=c++11', '-I'+includedir, '-I/usr/local/lib/clang/3.7.0/include',
         '-D__STDC_LIMIT_MACROS', '-D__STDC_CONSTANT_MACROS']

# %%
from vplants.autowig.front_end import *
asg = AbstractSemanticGraph()
asg.front_end('pyclang', *headers, flags=flags, complete=False, silent=False)
# Out:
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::clone::00c3e951-d118-5330-987e-1001dd7ee46e::__fn'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:337: NotImplementedTypeWarning: 'ConstantArray' for variable '::__tzname'
#   warnings.warn(str(warning) + ' for variable \'' + spelling + '\'', warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:337: NotImplementedTypeWarning: 'ConstantArray' for variable '::tzname'
#   warnings.warn(str(warning) + ' for variable \'' + spelling + '\'', warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::pthread_create::00da3a71-e082-56aa-aa2b-0038fd2d4a92::__start_routine'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::pthread_once::e2b149c3-2876-56b2-8472-d22012f24023::__init_routine'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::pthread_key_create::e8af30f6-4013-5a7e-9a62-8d5961db151d::__destr_function'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::pthread_atfork::d28b17f1-6335-5521-9eda-a4cc16eb4d11::__prepare'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::__gthrw_pthread_once::6bdcf33c-587c-5d47-8d74-7886d17b833b::parm_1'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::__gthrw_pthread_create::df786e17-8acd-5ecf-85e2-ec6b3a756b51::parm_2'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::__gthrw_pthread_key_create::c87faaa9-f51d-5157-a4bf-4845e33bc9b4::parm_1'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::__gthrw___pthread_key_create::9b9c79cb-a291-5c4a-9558-76cc458da61a::parm_1'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::__gthread_create::34ad6df8-fbca-5ee1-87d1-4ea88a62cd1c::__func'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::__gthread_once::9b68526e-d34e-5906-b2ba-daa3eccb8a87::__func'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::__gthread_key_create::eddd4ea0-19a1-5add-8e0a-d0c8ec611c0d::__dtor'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::atexit::8420d834-ed4b-56f8-aa42-662857083aed::__func'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::at_quick_exit::b9eaee4c-d4eb-53da-bb95-91051da60c96::__func'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::on_exit::7216441b-e5fe-59fc-897a-c998f1deec1d::__func'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'FunctionProto' for parameter '::bsearch::84e0e109-bad5-5b24-a53b-4221d682b4c3::__compar'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'FunctionProto' for parameter '::qsort::01b75a16-a197-594f-a9b3-6bec98c89dd3::__compar'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'FunctionProto' for parameter '::qsort_r::caf10887-9c81-50b1-9d57-2e2b825edbf0::__compar'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:337: NotImplementedTypeWarning: 
__t'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTemplateWarning: Packnested for parameter '::std::get::73a30d3e-a722-5b84-a767-b9ee92b6e8e4::__t'
#   warning.__class__)
# done!
# 0 1 done!
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTemplateWarning: Packnested for parameter '::std::__get_helper::dc77904d-cd54-5273-94b3-6c8bc5828935::__t'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTemplateWarning: Packnested for parameter '::std::get::61616181-7233-5442-bfaa-d6e46748a5bb::__t'
#   warning.__class__)

# %%
asg

# %%
from vplants.autowig.middle_end import *
asg.middle_end('bootstrap')

# %%
asg

# %%
from vplants.autowig.back_end import *
asg.back_end('bootstrap', '../../pyclanglite/src/wrapper/pyclanglite.cpp', on_disk=True)
# Out:
# <table>
# 	<tr>
# 		<th>Total files generated</th>
# 		<td>160 <i>(f)</i></td>
# 	</tr>
# 	<tr>
# 		<th>Total physical source lines of code</th>
# 		<td>2728 <i>(l)</i></td>
# 	</tr>
# 	<tr>
# 		<th>Elapsed time</th>
# 		<td>0.05 <i>(s)</i></td>
# 	</tr>
# 	<tr>
# 		<th> Basic COCOMO model software project</th>
# 		<td>semi-detached</td>
# 	</tr>
# 	<tr>
# 		<th>Development effort estimate</th>
# 		<td>9.23 <i>(p/m)</i></td>
# 	</tr>
# 	<tr>
# 		<th>Schedule estimate</th>
# 		<td>5.44 <i>(m)</i></td>
# 	</tr>
# 	<tr>
# 		<th>Estimated average number of developers</th>
# 		<td>1.7 <i>(p)</i></td>
# 	</tr>
# </table>

# %%
asg

# %%
from vplants.autowig.scons import *
asg.add_sconstruct('../../pyclanglite')
asg.scons('-j', '3')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
#
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# td.linenos { background-color: #f0f0f0; padding-right: 10px; }
# span.lineno { background-color: #f0f0f0; padding: 0 5px 0 5px; }
# pre { line-height: 125%; }
# body .hll { background-color: #ffffcc }
# body  { background: #f8f8f8; }
# body .c { color: #408080; font-style: italic } /* Comment */
# body .err { border: 1px solid #FF0000 } /* Error */
# body .k { color: #008000; font-weight: bold } /* Keyword */
# body .o { color: #666666 } /* Operator */
# body .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# body .cp { color: #BC7A00 } /* Comment.Preproc */
# body .c1 { color: #408080; font-style: italic } /* Comment.Single */
# body .cs { color: #408080; font-style: italic } /* Comment.Special */
# body .gd { color: #A00000 } /* Generic.Deleted */
# body .ge { font-style: italic } /* Generic.Emph */
# body .gr { color: #FF0000 } /* Generic.Error */
# body .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# body .gi { color: #00A000 } /* Generic.Inserted */
# body .go { color: #888888 } /* Generic.Output */
# body .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# body .gs { font-weight: bold } /* Generic.Strong */
# body .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# body .gt { color: #0044DD } /* Generic.Traceback */
# body .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #008000 } /* Keyword.Pseudo */
# body .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #B00040 } /* Keyword.Type */
# body .m { color: #666666 } /* Literal.Number */
# body .s { color: #BA2121 } /* Literal.String */
# body .na { color: #7D9029 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# body .no { color: #880000 } /* Name.Constant */
# body .nd { color: #AA22FF } /* Name.Decorator */
# body .ni { color: #999999; font-weight: bold } /* Name.Entity */
# body .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# body .nf { color: #0000FF } /* Name.Function */
# body .nl { color: #A0A000 } /* Name.Label */
# body .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# body .nt { color: #008000; font-weight: bold } /* Name.Tag */
# body .nv { color: #19177C } /* Name.Variable */
# body .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# body .w { color: #bbbbbb } /* Text.Whitespace */
# body .mf { color: #666666 } /* Literal.Number.Float */
# body .mh { color: #666666 } /* Literal.Number.Hex */
# body .mi { color: #666666 } /* Literal.Number.Integer */
# body .mo { color: #666666 } /* Literal.Number.Oct */
# body .sb { color: #BA2121 } /* Literal.String.Backtick */
# body .sc { color: #BA2121 } /* Literal.String.Char */
# body .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# body .s2 { color: #BA2121 } /* Literal.String.Double */
# body .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# body .sh { color: #BA2121 } /* Literal.String.Heredoc */
# body .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# body .sx { color: #008000 } /* Literal.String.Other */
# body .sr { color: #BB6688 } /* Literal.String.Regex */
# body .s1 { color: #BA2121 } /* Literal.String.Single */
# body .ss { color: #19177C } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .vc { color: #19177C } /* Name.Variable.Class */
# body .vg { color: #19177C } /* Name.Variable.Global */
# body .vi { color: #19177C } /* Name.Variable.Instance */
# body .il { color: #666666 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span class="go">scons: Reading SConscript files ...</span>
# <span class="go">scons: done reading SConscript files.</span>
# <span class="go">scons: Building targets ...</span>
# <span class="go">g++ -o build-scons/src/wrapper/export_class_clang_member_pointer_type.os -c -DNDEBUG -O2 -std=c++0x -DNDEBUG -O2 -fPIC -ftemplate-depth-100 -DBOOST_PYTHON_DYNAMIC_LIB -Ibuild-scons/include -I/usr/include -I/usr/include/python2.7 -I/usr/local/include build-scons/src/wrapper/export_class_clang_member_pointer_type.cpp</span>
# <span class="go">g++ -o build-scons/src/wrapper/export_class_clang_enum_type.os -c -DNDEBUG -O2 -std=c++0x -DNDEBUG -O2 -fPIC -ftemplate-depth-100 -DBOOST_PYTHON_DYNAMIC_LIB -Ibuild-scons/include -I/usr/include -I/usr/include/python2.7 -I/usr/local/include build-scons/src/wrapper/export_class_clang_enum_type.cpp</span>
# <span class="go">g++ -o build-scons/src/wrapper/export_class_clang_var_decl.os -c -DNDEBUG -O2 -std=c++0x -DNDEBUG -O2 -fPIC -ftemplate-depth-100 -DBOOST_PYTHON_DYNAMIC_LIB -Ibuild-scons/include -I/usr/include -I/usr/include/python2.7 -I/usr/local/include build-scons/src/wrapper/export_class_clang_var_decl.cpp</span>
# <span class="go">g++ -o build-scons/src/wrapper/export_class_clang_redeclarable_ae_973c_41_22af_5bd_6_87df_3498e_7046d_7d.os -c -DNDEBUG -O2 -std=c++0x -DNDEBUG -O2 -fPIC -ftemplate-depth-100 -DBOOST_PYTHON_DYNAMIC_LIB -Ibuild-scons/include -I/usr/include -I/usr/include/python2.7 -I/usr/local/include build-scons/src/wrapper/export_class_clang_redeclarable_ae_973c_41_22af_5bd_6_87df_3498e_7046d_7d.cpp</span>
# <span class="go">g++ -o build-scons/src/wrapper/export_class_clang_file_scope_asm_decl.os -c -DNDEBUG -O2 -std=c++0x -DNDEBUG -O2 -fPIC -ftemplate-depth-100 -DBOOST_PYTHON_DYNAMIC_LIB -Ibuild-scons/include -I/usr/include -I/usr/include/python2.7 -I/usr/local/include build-scons/src/wrapper/export_class_clang_file_scope_asm_decl.cpp</span>
# <span class="go">g++ -o build-scons/src/wrapper/export_class_clang_split_qual_type.os -c -DNDEBUG -O2 -std=c++0x -DNDEBUG -O2 -fPIC -ftemplate-depth-100 -DBOOST_PYTHON_DYNAMIC_LIB -Ibuild-scons/include -I/usr/include -I/usr/include/python2.7 -I/usr/local/include build-scons/src/wrapper/export_class_clang_split_qual_type.cpp</span>
# <span class="go">g++ -o build-scons/src/wrapper/export_class_clang_type_of_expr_type.os -c -DNDEBUG -O2 -std=c++0x -DNDEBUG -O2 -fPIC -ftemplate-depth-100 -DBOOST_PYTHON_DYNAMIC_LIB -Ibuild-scons/include -I/usr/include -I/usr/include/python2.7 -I/usr/local/include build-scons/src/wrapper/export_class_clang_type_of_expr_type.cpp</span>
# <span class="go">g++ -o build-scons/src/wrapper/export_class_clang_obj_cat_defs_field_decl.os -c -DNDEBUG -O2 -std=c++0x -DNDEBUG -O2 -fPIC -ftemplate-depth-100 -DBOOST_PYTHON_DYNAMIC_LIB -Ibuild-scons/include -I/usr/include -I/usr/include/python2.7 -I/usr/local/include build-scons/src/wrapper/export_class_clang_obj_cat_defs_field_decl.cpp</span>
# <span class="go">g++ -o build-scons/src/wrapper/export_class_clang_redeclarable_973fe_479_9d_35_5f_3a_8c_60_bd_6b_45c_88258.os -c -DNDEBUG -O2 -std=c++0x -DNDEBUG -O2 -fPIC -ftemplate-depth-100 -DBOOST_PYTHON_DYNAMIC_LIB -Ibuild-scons/include -I/usr/include -I/usr/include/python2.7 -I/usr/local/include build-scons/src/wrapper/export_class_clang_redeclarable_973fe_479_9d_35_5f_3a_8c_60_bd_6b_45c_88258.cpp</span>
# <span class="go">g++ -o build-scons/src/wrapper/export_class_clang_class_template_decl.os -c -DNDEBUG -O2 -std=c++0x -DNDEBUG -O2 -fPIC -ftemplate-depth-100 -DBOOST_PYTHON_DYNAMIC_LIB -Ibuild-scons/include -I/usr/include -I/usr/include/python2.7 -I/usr/local/include build-scons/src/wrapper/export_class_clang_class_template_decl.cpp</span>
# <span class="go">g++ -o build-scons/src/wrapper/export_class_clang_cxxmethod_decl.os -c -DNDEBUG -O2 -std=c++0x -DNDEBUG -O2 -fPIC -ftemplate-depth-100 -DBOOST_PYTHON_DYNAMIC_LIB -Ibuild-scons/include -I/usr/include -I/usr/include/python2.7 -I/usr/local/include build-scons/src/wrapper/export_class_clang_cxxmethod_decl.cpp</span>
# <span clas

# %%
asg

# %%
includedir = "/usr/local/include"

headers = [str(header.abspath()) for header in (path(includedir)/'clang').walkfiles('*.h')]

flags = ['-x', 'c++', '-g', '-std=c++11', '-I'+includedir, '-I/usr/local/lib/clang/3.7.0/include',
         '-D__STDC_LIMIT_MACROS', '-D__STDC_CONSTANT_MACROS']

# %%
asg.front_end('pyclang', *headers, flags=flags, silent=False)
# Out:
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::atexit::8420d834-ed4b-56f8-aa42-662857083aed::__func'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::at_quick_exit::b9eaee4c-d4eb-53da-bb95-91051da60c96::__func'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::on_exit::7216441b-e5fe-59fc-897a-c998f1deec1d::__func'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'FunctionProto' for parameter '::bsearch::84e0e109-bad5-5b24-a53b-4221d682b4c3::__compar'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'FunctionProto' for parameter '::qsort::01b75a16-a197-594f-a9b3-6bec98c89dd3::__compar'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'FunctionProto' for parameter '::qsort_r::caf10887-9c81-50b1-9d57-2e2b825edbf0::__compar'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::clone::00c3e951-d118-5330-987e-1001dd7ee46e::__fn'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:337: NotImplementedTypeWarning: 'ConstantArray' for variable '::__tzname'
#   warnings.warn(str(warning) + ' for variable \'' + spelling + '\'', warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:337: NotImplementedTypeWarning: 'ConstantArray' for variable '::tzname'
#   warnings.warn(str(warning) + ' for variable \'' + spelling + '\'', warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::pthread_create::00da3a71-e082-56aa-aa2b-0038fd2d4a92::__start_routine'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::pthread_once::e2b149c3-2876-56b2-8472-d22012f24023::__init_routine'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::pthread_key_create::e8af30f6-4013-5a7e-9a62-8d5961db151d::__destr_function'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::pthread_atfork::d28b17f1-6335-5521-9eda-a4cc16eb4d11::__prepare'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::__gthrw_pthread_once::6bdcf33c-587c-5d47-8d74-7886d17b833b::parm_1'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::__gthrw_pthread_create::df786e17-8acd-5ecf-85e2-ec6b3a756b51::parm_2'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTypeWarning: 'Paren' for parameter '::__gthr
__t'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTemplateWarning: Packnested for parameter '::std::get::d5bf0f75-db29-50bc-a432-37a8ecf92373::__t'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTemplateWarning: Packnested for parameter '::std::__get_helper::3820f3ee-be3d-582e-a19d-9692bead7ae4::__t'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTemplateWarning: Packnested for parameter '::std::get::8f67da0a-e07e-592e-99dd-7a57ba20780c::__t'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTemplateWarning: Packnested for parameter '::std::__get_helper::cd41790d-cd45-570d-8566-e7a72b7f1b05::__t'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTemplateWarning: Packnested for parameter '::std::get::aa5565eb-a057-5e49-a009-4c5e85e5b497::__t'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTemplateWarning: Packnested for parameter '::std::__get_helper::4de794f4-c766-5417-9964-6502c1995deb::__t'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTemplateWarning: Packnested for parameter '::std::get::9b253629-f999-5f27-80a1-b0f0b8abfede::__t'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTemplateWarning: Packnested for parameter '::std::__get_helper::04339311-0a80-5e64-8b3b-bc5d693966f6::__t'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTemplateWarning: Packnested for parameter '::std::get::b611092d-1299-5ecb-92fa-a581b6487ba7::__t'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTemplateWarning: Packnested for parameter '::std::__get_helper::589a733a-5656-50b6-9d08-3b9905680f39::__t'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTemplateWarning: Packnested for parameter '::std::get::6f35d6ce-42cc-56d5-86b0-e6f4b7a7129a::__t'
#   warning.__class__)
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTemplateWarning: Packnested for parameter '::std::__get_helper::55a821ef-ebc2-56de-b026-4d9d15201a94::__t'
#   warning.__class__)
# done!
# 0 1 done!
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/pyclang_front_end.py:490: NotImplementedTemplateWarning: Packnested for parameter '::std::get::0a696c6f-7f71-58aa-9e82-74c4a62108e9::__t'
#   warning.__class__)

# %%
asg.middle_end()

# %%
asg.back_end('boost_python', '../../pyclang/src/wrapper/pyclang.cpp', on_disk=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-e23b53fcd5b0> in <module>()
# ----> 1 asg.back_end('boost_python', '../../pyclang/src/wrapper/pyclang.cpp', on_disk=True)
#
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/back_end.pyc in back_end(self, identifier, *args, **kwargs)
#      73 def back_end(self, identifier=None, *args, **kwargs):
#      74     back_end = getattr(self, '_' + identifier + '_back_end')
# ---> 75     return back_end(*args, **kwargs)
#      76
#      77 AbstractSemanticGraph.back_end = back_end
#
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/boost_python_back_end.py in _boost_python_back_end(self, filename, *args, **kwargs)
#     528                 if not isinstance(node, ClassTemplateSpecializationProxy) or not node.as_held_type:
#     529                     parent = node.parent
# --> 530                     if not isinstance(parent, ClassProxy) or node.access == 'public':
#     531                         node.to_python = True
#     532                         exportnode = modulenode.add_export(directory + 'export_class_' + to_path(node) + suffix, proxy = export)
#
# /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/asg.pyc in __getattr__(self, attr)
#      49     def __getattr__(self, attr):
#      50         try:
# ---> 51             return self.asg._nodes[self.node][attr]
#      52         except:
#      53             raise #AttributeError('\'' + self.__class__.__name__ + '\' object has no attribute \'' + attr + '\'')
#
# KeyError: 'access'

# %%
# %debug
# Out:
# > /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/asg.py(53)__getattr__()
#      52         except:
# ---> 53             raise #AttributeError('\'' + self.__class__.__name__ + '\' object has no attribute \'' + attr + '\'')
#      54
#
# ipdb> u
# > /home/pfernique/Desktop/Git/autowig/src/vplants/autowig/boost_python_back_end.py(530)_boost_python_back_end()
#     529                     parent = node.parent
# --> 530                     if not isinstance(parent, ClassProxy) or node.access == 'public':
#     531                         node.to_python = True
#
# ipdb> node
# struct ::clang::ast_type_traits::DynTypedNode::DynCastPtrConverter<clang::UsingDecl, clang::Decl>
# ipdb> node.parent
# class ::clang::ast_type_traits::DynTypedNode
# ipdb> node.parent.__class__
# <class 'vplants.autowig.asg.ClassProxy'>
# ipdb> node.__class__
# <class 'vplants.autowig.asg.ClassTemplateSpecializationProxy'>

# %%
asg.add_sconstruct('../../pyclang')
asg.scons('-j', '3')

# %% [markdown]
# ### Structure Analysis

# %%
asg = pyclang.AbstractSemanticGraph()
asg.add_sconstruct('/home/pfernique/Desktop/GForge/vplants/vplants/trunk/stat_tool')
asg.scons('-j', '2')
includedir = asg.add_directory('/home/pfernique/Desktop/GForge/vplants/vplants/trunk/stat_tool/build-scons/include')
includedir.walkfiles('*.h', on_disk=True)
flags = ['-x', 'c++', '-g', '-std=c++11', '-I/usr/include',
         '-I/usr/lib/llvm-3.5/lib/clang/3.5.0/include',
         '-I/home/pfernique/Desktop/GForge/vplants/vplants/trunk/tool/build-scons/include',
         '-I/usr/local/openalea/include', '-I'+includedir.globalname]
includedir.parse(flags=flags)
asg.clean()

# %%
asg.remove_invalid_pointers()
bpm = asg.boost_python_module('/home/pfernique/Desktop/GForge/vplants/vplants/trunk/stat_tool/src/boost_python/stat_tool.cpp', '(.*)')
bpm.write(force=True)
asg.add_sconstruct('/home/pfernique/Desktop/GForge/vplants/vplants/trunk/stat_tool')
asg.scons('-j', '2')

# %%
filenode = asg['/home/pfernique/Desktop/GForge/vplants/vplants/trunk/stat_tool/src/boost_python/export_class_stat_tool_chain.cpp']
filenode

# %% [markdown]
# ### Septo3d

# %%
from path import path
cwd = '/home/pfernique/Desktop/GForge/openalea-packages/trunk/septo3d/src/cpp/' # 'home/pfernique/Desktop/GForge/llvm/clang/include/clang/AST/'
includedir = path(cwd)
includes = list(includedir.walkfiles('*.h'))

# %%
print 'Include files:', '\n               '.join(str(include) for include in includes)

# %%
from vplants.autowig.ast import AbstractSyntaxTree
ast = AbstractSyntaxTree('../src/cpp/AST.h', language='c')
ast

# %%
from vplants.autowig.asg import AbstractSemanticGraph
asg = AbstractSemanticGraph()
cwd = asg.add_file('../src/cpp/AST.h')
#asg

# %%
from path import path
path('.')

# %%
headers = cwd.glob('*.h', on_disk=True)
asg

# %%
cwd.parse(side_effect=False, language='c++')
#asg

# %%
[d.access for d in asg['::clang::StringRef'].declarations()]

# %%
print len(asg.nodes()), 'against',
asg.purge(convert=False, typedefs=False)
print len(asg.nodes())

# %%
node = asg['::clang::ast_type_traits::DynTypedNode']
node.header

# %%
for d in node.declarations():
    print d.localname, d.access

# %%
asg.nodes()[:10]

# %%
node.declarations()

# %%
list(node.cursor.get_children())

# %%
raise

# %% [markdown]
# ## Future works

# %%
from path import path
p = path(asg['/home/pfernique/Desktop/GForge/openalea-packages/trunk/septo3d/src/cpp/'].globalname)
for n in p.glob('*.h'):
    if n.isfile():
        asg.add_file(str(n.abspath()))

# %%
asg.nodes()

# %%
tu = index.read('/home/pfernique/Desktop/test.ast')

# %% [markdown]
# ### Building the abstract semantic graph from the abstract syntax tree

# %%
from vplants.autowig.asg import AbstractSemanticGraph
asg = AbstractSemanticGraph(ast)
asg.purge(convert=False)
#asg

# %%
'/home/pfernique/Desktop/GForge/openalea-packages/trunk/septo3d/src/cpp'.rstrip('cpp/')

# %% [markdown]
# ### Traverse the abstract semantic graph to generate Python bindings

# %%
from vplants.autowig.boost_python import BoostPythonTraversal
for directory in asg['(.*)src/$']:
    traversal = BoostPythonTraversal(directory=directory.globalname + 'boost_python/')
    traversal(asg)
#asg

# %%
asg['(.*)export_class_splashlut'].pop()

# %%
ast = AbstractSyntaxTree(*includes, language='C')
asg = AbstractSemanticGraph(ast)
asg.purge()

# %%
import re
import os
from vplants.autowig.boost_python import BoostPythonExportFileProxy, BoostPythonTraversal

class BoostPythonExportSepto3dFileProxy(BoostPythonExportFileProxy):
    """
    """
    
    def include(self, include):
        return "<" + re.sub('(.*)septo3d/src/cpp/(.*)', r'septo3d/\2', include) + ">"
    
traversal = BoostPythonTraversal(node='::',
                                 directory=asg['(.*)septo3d/src/$'].pop().globalname + os.sep + 'boost_python',
                                 export_proxy=BoostPythonExportSepto3dFileProxy)

traversal(asg)
asg['(.*)export_class_splashlut'].pop()

# %%
asg['/home/pfernique/Desktop/GForge/openalea-packages/trunk/septo3d/src/boost_python/export_class_splashlut.cxx'].exports

# %% [markdown]
# ### Building the abstract syntax tree from C++ headers

# %%
includedir = path('/home/pfernique/Desktop')
includes = ['/home/pfernique/Desktop/test.cpp']
print 'Include files:', '\n               '.join(str(include) for include in includes)
ast = AbstractSyntaxTree(*includes, language='C++')
ast

# %%
cursor = ast[6].cursor

# %%
c = list(cursor.get_specializations())
for ci in c:
    print ci.displayname, ci.kind

# %%
ci.kind.is_declaration()

# %%
from vplants.autowig.ast import conf
conf.lib.clang_Cursor_v

# %%
ast[31].cursor.type.get_declaration().type.spelling

# %%
cursor.

# %%
c = list(t.get_declaration().get_children())

# %%
c

# %%
asg = AbstractSemanticGraph(ast)

# %% [raw]
# from path import path
# includedir = path('/home/pfernique/Desktop/GForge/vplants/vplants/trunk/stat_tool/src/cpp')
# includes = list(includedir.walkfiles('*.cpp'))
# print 'Include files:', '\n               '.join(str(include) for include in includes)
# flags = ['-x', 'c++', '-std=c++11', '-Wdocumentation',
#          '-fPIC', '-ftemplate-depth-100', '-DQT_GUI_LIB', '-DBOOST_PYTHON_DYNAMIC_LIB', '-DQT_SHARED',
#          '-DMESSAGE' ,'-I/home/pfernique/Desktop/GForge/vplants/vplants/trunk/stat_tool/build-scons/include',
#          '-I/usr/include', '-I/usr/include/python2.7',
#          '-I/home/pfernique/Desktop/GForge/vplants/vplants/trunk/tool/build-scons/include',
#          '-I/usr/include', '-I/usr/local/openalea/include', '-I/usr/include/qt4', '-I/usr/include/qt4',
#          '-I/usr/include/qt4/QtOpenGL', '-I/usr/include/qt4/QtGui', '-I/usr/include/qt4/QtCore']
# ast = AbstractSyntaxTree(*includes, flags=flags, language='C++')
# ast

# %% [raw]
# from vplants.autowig.asg import AbstractSemanticGraph
# asg = AbstractSemanticGraph(ast)
# print len(asg.nodes())
# asg.purge(convert=False)
# print len(asg.nodes())

# %%
from path import path
includedir = path('/home/pfernique/Desktop/GForge/llvm/clang/include/clang/AST')
includes = list(includedir.walkfiles('*.h'))
print 'Include files:', '\n               '.join(str(include) for include in includes)
ast = AbstractSyntaxTree(*includes, language='C++')
ast

# %%
asg = AbstractSemanticGraph(ast)
print len(asg.nodes())

# %%
asg.nodes()

# %%
gray = [node.id for node in asg['^::clang::[a-zA-Z]*Decl$']]
gray

# %%
asg.purge(convert=False, typedefs=False, gray=gray)

# %%
asg.nodes()

# %% [markdown]
# #Yop
#
# Nop
